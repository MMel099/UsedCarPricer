# %% [markdown]
# # Used Car Price Estimator
#
# ### Summary
# [Auto.dev](https://www.auto.dev/) is an API with recent car listing data. Data on Toyota Camrys (n~1000) was gathered and a model was developed to predict car price. Multiple linear regression was used with year, mileage, and trim as independent predictors. The model's fitted values were used to identify cars with the largest discounts (residuals).
#
# ### Next Steps
# * A daily check-in that can generate discount prices on new cars
# * A tracker of new listing data for seasonal analysis
#
# ### Code:
# #### Part 1: Setup

# %%
# Jupyter occasionally has errors with retrieving packages installed in other places/environments
# !{sys.executable} -m pip install --upgrade seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.17.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Forest2/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# Import relevant libraries
import requests
import json
import pandas as pd
import numpy as np
from pandas import json_normalize
import statsmodels.api as sm
import matplotlib.pyplot as plt
import sys
import math
from scipy.stats import chi2
import seaborn as sns

# %% [markdown]
# #### Part 2: Call API for Data
# Data on ~1000 Toyota Camry listings was gathered. Cars before 2016 were not considered. All mileages were considered for the model building. There were four trims used for model building (SE, LE, XSE, XLE). All other trims had low and unreliable counts and were thus excluded.

# %%
# Base URL for API requests
url = "https://auto.dev/api/listings"
# General parameters for model trainings
params = {
    'apikey': 'ZrQEPSkKbWF4bWVsbmlrYXNAZ21haWwuY29t',
    'sort_filter': 'created_at:desc',
    'year_min': 2016,
    'make': 'Toyota',
    'model': 'Camry',
    #'city': 'Boston',
    #'state': 'MA',
    #'location': 'Boston, MA',
    'longitude': -71.058884,
    'latitude': 42.360081,
    'radius': 200,
    'transmission[]': 'automatic',
    'exclude_no_price': 'true'
    # Remove or properly set empty parameters
}

# Each page has 20 entries therefore 50 pages need to be collected
pages = list(range(1, 51))

# Initialize an empty list to store all records
all_data = []

# Loop over each page, fetch data, and append to the list
for page in pages:
    params['page'] = page
    response = requests.get(url, params=params)
    result = response.json()
    
    if 'records' in result:
        all_data.extend(result['records'])
    else:
        print(f"Warning: 'records' key not found on page {page}")

# Normalize the JSON data into a DataFrame
df = json_normalize(all_data)

# Now `df` contains all the records from the fetched pages
df  # To display the first few rows of the DataFrame
# Out:
#             id                vin               displayColor  year    make  \
# 0    295410867  4T1KZ1AK4PU075125    Midnight Black Metallic  2023  Toyota
# 1    295410866  4T1C11AK7MU423619          Predawn Gray Mica  2021  Toyota
# 2    295410758  4T1DBADK2SU006855                    Ice Cap  2025  Toyota
# 3    295405971  4T1T11BKXNU048163                      WHITE  2022  Toyota
# 4    295405421  4T1G11BK3RU118223    Midnight Black Metallic  2024  Toyota
# ..         ...                ...                        ...   ...     ...
# 995  291480983  4T1B11HK7JU645039    Midnight Black Metallic  2018  Toyota
# 996  291457309  4T1G11BK2RU108671                       None  2024  Toyota
# 997  291449119  4T1DBADK3SU31A457                      White  2025  Toyota
# 998  291436725  4T1C11AK6PU760769                      White  2023  Toyota
# 999  291428904  4T1S11AKXNU687656  Celestial Silver Metallic  2022  Toyota
#
#      model    price       mileage              city      lat  ...  \
# 0    Camry  $39,900   6,071 Miles            Nashua  42.7286  ...
# 1    Camry  $23,600  44,746 Miles            Nashua  42.7286  ...
# 2    Camry  $33,669           New             Bronx  40.8700  ...
# 3    Camry  $23,499  57,170 Miles          Brooklyn  40.6064  ...
# 4    Camry  $29,990   8,213 Miles       Schenectady  42.7557  ...
# ..     ...      ...           ...               ...      ...  ...
# 995  Camry  $17,995  21,203 Miles            Inwood  40.6230  ...
# 996  Camry  $29,350  17,025 Miles      Little Ferry  40.8539  ...
# 997  Camry  $34,973           New  West Springfield  42.1420  ...
# 998  Camry  $20,514  30,701 Miles         Irvington  40.7247  ...
# 999  Camry  $26,777  30,061 Miles           Norwood  42.1819  ...
#
#      trackingParams.remoteDealerId trackingParams.dealerName  \
# 0                           327343                      None
# 1                           327343                      None
# 2                            65202                      None
# 3                           453444                      None
# 4                           190707                      None
# ..                             ...                       ...
# 995                         342141                      None
# 996                         444472                      None
# 997                         305851                      None
# 998                         405793                      None
# 999                          54418                      None
#
#     trackingParams.remoteSku  trackingParams.experience  \
# 0                   N19155TC                      local
# 1                    N21449C                      local
# 2                     241012                      local
# 3                      53710                      local
# 4                  RU118223R                      local
# ..                       ...                        ...
# 995                   645039                      local
# 996                   108671                      local
# 997                 SU31A457                      local
# 998                   760769                      local
# 999                  PT43156                      local
#
#     trackingParams.rooftopUniqueName trackingParams.rooftopUuid  \
# 0                               None                       None
# 1                               None                       None
# 2                               None                       None
# 3                               None                       None
# 4                               None                       None
# ..                               ...                        ...
# 995                             None                       None
# 996                             None                       None
# 997                             None                       None
# 998                             None                       None
# 999                             None                       None
#
#      trackingParams.dealerUniqueName trackingParams.dealerUuid  \
# 0                               None                      None
# 1                               None                      None
# 2                               None                      None
# 3                               None                      None
# 4                               None                      None
# ..                               ...                       ...
# 995                             None                      None
# 996                             None                      None
# 997                             None                      None
# 998                             None                      None
# 999                             None                      None
#
#      trackingParams.dealerGroupUniqueName trackingParams.dealerGroupUuid
# 0                                    None                           None
# 1                                    None                           None
# 2                                    None                           None
# 3                                    None                           None
# 4                                    None                           None
# ..                                    ...                            ...
# 995                                  None                           None
# 996                                  None                           None
# 997                                  None                           None
# 998                                  None                           None
# 999                                  None                           None
#
# [1000 rows x 79 columns]

# %% [markdown]
# #### Part 3: Clean data
# Three car features are included in this model:
# - Model Year
# - Mileage
# - Body Trim

# %%
def convert_mileage(value):
    value = value.strip()
    if value.lower() == 'new':
        return 0
    try:
        # Remove non-numeric characters and convert to int
        return int(value.replace(',', '').replace(' Miles', ''))
    except ValueError:
        # Handle unexpected cases
        return None

def convert_year(value):
    value = 2025 - value + 1
    return math.log(value)

def convert_price(value):
    if isinstance(value, str):
        value = value.replace('$', '').replace(',', '')
        try:
            return float(value)
        except ValueError:
            return None
    return None

# %%
X = df[['year', 'mileageUnformatted', 'priceUnformatted', 'trim']]

X = X.dropna()

# %%
# Define the trims you want to include
trims_to_filter = ['SE', 'LE', 'XSE', 'XLE']

# Filter out any unwanted trims
X_mod = X[X['trim'].isin(trims_to_filter)]
y = X_mod.pop('priceUnformatted')

# Convert remaining trims into categorical data types
X_mod['trim'] = X_mod['trim'].astype('category')
X_mod = pd.get_dummies(X_mod, columns=['trim'], drop_first=True)

# Convert boolean columns to 1/0
X_mod['trim_SE'] = X_mod['trim_SE'].astype(int)
X_mod['trim_XLE'] = X_mod['trim_XLE'].astype(int)
X_mod['trim_XSE'] = X_mod['trim_XSE'].astype(int)


X_mod = sm.add_constant(X_mod)

# Allow each model year to have an additional affect beyond the existing logarithmic effect
temp = X_mod['year']
X_mod = pd.get_dummies(X_mod, columns=['year'], drop_first=False)
X_mod.pop('year_2025')

X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
X_mod['year'] = temp.apply(convert_year)
# Out:
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['trim'] = X_mod['trim'].astype('category')
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2016, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2017, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    1
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2018, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2019, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2020, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      1
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: year_2021, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      1
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    1
# Name: year_2022, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      0
# 5      0
# 8      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    1
# 999    0
# Name: year_2023, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_35267/1189541106.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1      0
# 3      0
# 4      1
# 5      0
# 8      0
#       ..
# 995    0
# 996    1
# 997    0
# 998    0
# 999    0
# Name: year_2024, Length: 742, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]] = X_mod.iloc[:, [5, 6, 7, 8, 9, 10, 11, 12, 13]].astype(int)

# %% [markdown]
# #### Part 4: Build model

# %%
regression_model = sm.GLM(y, X_mod, family=sm.families.Gaussian()).fit()

# Print the summary of the model
print(regression_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       priceUnformatted   No. Observations:                  742
# Model:                            GLM   Df Residuals:                      728
# Model Family:                Gaussian   Df Model:                           13
# Link Function:               Identity   Scale:                      4.7603e+06
# Method:                          IRLS   Log-Likelihood:                -6750.2
# Date:                Sun, 25 Aug 2024   Deviance:                   3.4655e+09
# Time:                        12:17:34   Pearson chi2:                 3.47e+09
# No. Iterations:                     3   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               3.493e+04    186.662    187.117      0.000    3.46e+04    3.53e+04
# mileageUnformatted    -0.0689      0.003    -19.698      0.000      -0.076      -0.062
# trim_SE              587.9670    185.046      3.177      0.001     225.284     950.650
# trim_XLE            3688.9185    296.831     12.428      0.000    3107.141    4270.696
# trim_XSE            4641.6052    270.177     17.180      0.000    4112.069    5171.142
# year_2016           -581.9210    373.239     -1.559      0.119   -1313.455     149.613
# year_2017          -1336.4137    320.315     -4.172      0.000   -1964.219    -708.609
# year_2018           -172.4891    292.247     -0.590      0.555    -745.283     400.305
# year_2019            261.1740    285.518      0.915      0.360    -298.432     820.780
# year_2020             56.1576    295.954      0.190      0.850    -523.901     636.216
# year_2021            -97.4513    216.532     -0.450      0.653    -521.845     326.943
# year_2022            -84.2193    235.746     -0.357      0.721    -546.273     377.834
# year_2023           -442.8693    248.585     -1.782      0.075    -930.087      44.349
# year_2024          -1402.8466    349.182     -4.018      0.000   -2087.231    -718.463
# year               -5758.6783    158.136    -36.416      0.000   -6068.619   -5448.738
# ======================================================================================

# %% [markdown]
# #### Part 5: Evaluate model
#
# This section calculates the estimated price of a car based on input features. Cars with large discounts (difference between predicted price and actual price) are identified.

# %%
new_car = pd.DataFrame({'const': [1], 
                        'mileageUnformatted': [39000],
                        'trim_SE': [0],
                        'trim_XLE': [1],
                        'trim_XSE': [0],
                        'year_2016': [0],
                        'year_2017': [0],
                        'year_2018': [1],
                        'year_2019': [0],
                        'year_2020': [0],
                        'year_2021': [0],
                        'year_2022': [0],
                        'year_2023': [0],
                        'year_2024': [0],
                        'year': math.log(8)
                       })
# Predict the price
regression_model.predict(new_car)
# Out:
# 0    23781.970535
# dtype: float64

# %%
regression_model.resid_pearson[regression_model.resid_pearson < -5000]
# Out:
# 17    -5058.260503
# 207   -5092.175621
# 218   -5886.915986
# 252   -5123.398309
# 694   -6174.300329
# 779   -5870.016413
# 797   -5554.333122
# 929   -5328.128593
# 998   -5528.780504
# dtype: float64

# %%
pd.set_option('display.max_rows', 100)
df.iloc[207]
# Out:
# id                                                                              295050155
# vin                                                                     4T1G11AKXPU184377
# displayColor                                                                      Ice Cap
# year                                                                                 2023
# make                                                                               Toyota
# model                                                                               Camry
# price                                                                             $19,995
# mileage                                                                      53,103 Miles
# city                                                                               Newark
# lat                                                                               40.7697
# lon                                                                               -74.163
# primaryPhotoUrl                         https://InvImg2B.autofunds.net/InventoryImages...
# condition                                                                            used
# providerId                                                                            199
# createdAt                                                        2024-08-20T19:21:57.875Z
# updatedAt                                                        2024-08-22T19:31:32.075Z
# modelId                                                                               883
# dealerName                                                          Champion Auto Sales 2
# active                                                                               True
# state                                                                                  NJ
# trim                                                                                   SE
# clickoffUrl
# acceptsLeads                                                                         True
# bodyType                                                                            sedan
# bodyStyle                                                                           sedan
# regionName                                                                           None
# experience                                                                          local
# requiresAddressWithLead                                                             False
# providerGroupId                                                                       230
# mileageUnformatted                                                                53103.0
# mileageHumanized                                                                53k Miles
# priceMobile                                                                       $19,995
# priceUnformatted                                                                    19995
# recentPriceDrop                                                                      None
# vdpUrl                                                /toyota-camry#vin=4T1G11AKXPU184377
# showNewMileage                                                                      False
# eligibleForFinancing                                                                 True
# financingExperience                                                              softpull
# photoUrls                               [https://auto.dev/image/fetch/s--YZ01cQfr--/c_...
# isHot                                                                               False
# hrefTarget                                                    /listings/4T1G11AKXPU184377
# distanceFromOrigin                                                                    194
# humanizedSearchLocation                                                              None
# hideDistance                                                                         None
# noPriceText                                                                          None
# target                                                                               None
# monthlyPayment                                                                   -3602262
# clickOff                                                                            False
# emailOptDefault                                                                      True
# showThankyouPage                                                                    False
# showRsrp                                                                             True
# allowOneClickSubmit                                                                  True
# paidAllowOneClickSubmit                                                              True
# newPriceAsMsrp                                                                      False
# preCheckThankyou                                                                     True
# preCheckThankyouMobile                                                               True
# openInNewWindow                                                                     False
# alwaysAskForZip                                                                     False
# requireEmailOptIn                                                                   False
# providerName                                                                     auto_dev
# availableNationwide                                                                 False
# regional                                                                            False
# thumbnailUrl                            https://auto.dev/image/fetch/s--itcudYU2--/c_f...
# thumbnailUrlLarge                       https://auto.dev/image/fetch/s--YZ01cQfr--/c_f...
# quickPicksEligible                                                                   True
# dealerGroupUuid                                                                      None
# cplValue                                                                                3
# partnerType                                                                    metasearch
# trackingParams.idFromProvider                                                   393813201
# trackingParams.remoteDealerId                                                      383688
# trackingParams.dealerName                                                            None
# trackingParams.remoteSku                                                             3518
# trackingParams.experience                                                           local
# trackingParams.rooftopUniqueName                                                     None
# trackingParams.rooftopUuid                                                           None
# trackingParams.dealerUniqueName                                                      None
# trackingParams.dealerUuid                                                            None
# trackingParams.dealerGroupUniqueName                                                 None
# trackingParams.dealerGroupUuid                                                       None
# Name: 207, dtype: object

# %% [markdown]
# #### Part 6: Automate a daily newsletter

# %%
# %run daily_newsletter.py
# Out:
# Found an entry older than 24 hours, stopping the loop.
# /Users/maxmelnikas/Documents/Personal Projects/Cars/daily_newsletter.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['estimate_price'] = X_mod.apply(calculate_price, axis=1)
# /Users/maxmelnikas/Documents/Personal Projects/Cars/daily_newsletter.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['discount'] = X_mod['estimate_price'] - X_mod['priceUnformatted']

# %% [markdown]
# ## Appendix
