# %% [markdown]
# # Used Car Price Estimator
#
# ### Summary
# [Auto.dev](https://www.auto.dev/) is an API with recent car listing data. Data on Toyota Camrys (n~1000) was gathered and a model was developed to predict car price. Multiple linear regression was used with year, mileage, and trim as independent predictors. The model's fitted values were used to identify cars with the largest discounts (residuals).
#
# ### Next Steps
# * A daily check-in that can generate discount prices on new cars
# * A tracker of new listing data for seasonal analysis
#
# ### Code:
# #### Part 1: Setup

# %%
# Jupyter occasionally has errors with retrieving packages installed in other places/environments
# !{sys.executable} -m pip install --upgrade geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 1.1 MB/s eta 0:00:00 0:00:01
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 840.4 kB/s eta 0:00:00 0:00:01
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
# Import relevant libraries
import requests
import json
import pandas as pd
import numpy as np
from pandas import json_normalize
import statsmodels.api as sm
import matplotlib.pyplot as plt
import sys
import math
from scipy.stats import chi2
import seaborn as sns
from geopy import distance

# %% [markdown]
# #### Part 2: Call API for Data
# Data on ~1000 Toyota Camry listings was gathered. Cars before 2016 were not considered. All mileages were considered for the model building. There were four trims used for model building (SE, LE, XSE, XLE). All other trims had low and unreliable counts and were thus excluded.

# %%
# Base URL for API requests
url = "https://auto.dev/api/listings"
# General parameters for model trainings
params = {
    'apikey': 'ZrQEPSkKbWF4bWVsbmlrYXNAZ21haWwuY29t',
    'sort_filter': 'created_at:desc',
    'year_min': 2016,
    'make': 'Toyota',
    'model': 'Camry',
    #'city': 'Boston',
    #'state': 'MA',
    #'location': 'Boston, MA',
    'longitude': -71.058884,
    'latitude': 42.360081,
    'radius': 150,
    'transmission[]': 'automatic',
    'exclude_no_price': 'true'
    # Remove or properly set empty parameters
}

# Each page has 20 entries therefore 50 pages need to be collected
pages = list(range(1, 51))

# Initialize an empty list to store all records
all_data = []

# Loop over each page, fetch data, and append to the list
for page in pages:
    params['page'] = page
    response = requests.get(url, params=params)
    result = response.json()
    
    if 'records' in result:
        all_data.extend(result['records'])
    else:
        print(f"Warning: 'records' key not found on page {page}")

# Normalize the JSON data into a DataFrame
df = json_normalize(all_data)

# Now `df` contains all the records from the fetched pages
df  # To display the first few rows of the DataFrame
# Out:
#             id                vin             displayColor  year    make  \
# 0    295506920  4T1G11AK2NU693182                    Black  2022  Toyota
# 1    295506670  4T1DBADK7SU007709           Supersonic Red  2025  Toyota
# 2    295505121  4T1BF1FK8HU633822                   Silver  2017  Toyota
# 3    295504992  4T1BF1FK4GU239121                    Black  2016  Toyota
# 4    295482290  4T1DBADK7SU508972  Midnight Black Metallic  2025  Toyota
# ..         ...                ...                      ...   ...     ...
# 788  274973890  4T1BF1FK7HU341689                   Yellow  2017  Toyota
# 789  274186249  4T1C11AK1MU562127                    White  2021  Toyota
# 790  273201923  4T1B11HK3JU514108                 Burgundy  2018  Toyota
# 791  273198730  4T1C11BK0NU052867                    White  2022  Toyota
# 792  266685162  4T1BF1FK3HU766326                    White  2017  Toyota
#
#      model    price        mileage             city      lat  ...  \
# 0    Camry  $24,998   51,123 Miles      Marlborough  42.3336  ...
# 1    Camry  $41,523            New         Brockton  42.0550  ...
# 2    Camry  $19,875   63,131 Miles        Rochester  43.2538  ...
# 3    Camry  $12,495  120,739 Miles           Putnam  41.9247  ...
# 4    Camry  $33,894            New       Manchester  42.9518  ...
# ..     ...      ...            ...              ...      ...  ...
# 788  Camry  $13,495   86,067 Miles        Patchogue  40.7827  ...
# 789  Camry  $17,995   97,853 Miles        New Haven  41.2872  ...
# 790  Camry  $17,500   55,000 Miles         Seabrook  42.8749  ...
# 791  Camry  $24,999   46,482 Miles  North Attleboro  41.9580  ...
# 792  Camry  $15,495  112,219 Miles          Whitman  42.0768  ...
#
#      trackingParams.remoteDealerId trackingParams.dealerName  \
# 0                           448313                      None
# 1                            54419                      None
# 2                           305772                      None
# 3                           370282                      None
# 4                           175104                      None
# ..                             ...                       ...
# 788                         435091                      None
# 789                         292347                      None
# 790                         153486                      None
# 791                         280597                      None
# 792                         444801                      None
#
#     trackingParams.remoteSku  trackingParams.experience  \
# 0                       1244                      local
# 1                                                 local
# 2                     633822                      local
# 3                       3206                      local
# 4                   SU508972                      local
# ..                       ...                        ...
# 788                    37009                      local
# 789                   562127                      local
# 790                                               local
# 791                                               local
# 792                  3990421                      local
#
#     trackingParams.rooftopUniqueName trackingParams.rooftopUuid  \
# 0                               None                       None
# 1                               None                       None
# 2                               None                       None
# 3                               None                       None
# 4                               None                       None
# ..                               ...                        ...
# 788                             None                       None
# 789                             None                       None
# 790                             None                       None
# 791                             None                       None
# 792                             None                       None
#
#      trackingParams.dealerUniqueName trackingParams.dealerUuid  \
# 0                               None                      None
# 1                               None                      None
# 2                               None                      None
# 3                               None                      None
# 4                               None                      None
# ..                               ...                       ...
# 788                             None                      None
# 789                             None                      None
# 790                             None                      None
# 791                             None                      None
# 792                             None                      None
#
#      trackingParams.dealerGroupUniqueName trackingParams.dealerGroupUuid
# 0                                    None                           None
# 1                                    None                           None
# 2                                    None                           None
# 3                                    None                           None
# 4                                    None                           None
# ..                                    ...                            ...
# 788                                  None                           None
# 789                                  None                           None
# 790                                  None                           None
# 791                                  None                           None
# 792                                  None                           None
#
# [793 rows x 79 columns]

# %%
pd.set_option('display.max_rows', 100)
df.iloc[1]
# Out:
# id                                                                              295506670
# vin                                                                     4T1DBADK7SU007709
# displayColor                                                               Supersonic Red
# year                                                                                 2025
# make                                                                               Toyota
# model                                                                               Camry
# price                                                                             $41,523
# mileage                                                                               New
# city                                                                             Brockton
# lat                                                                                42.055
# lon                                                                               -71.056
# primaryPhotoUrl                         https://media.rti.toyota.com/config/pub/3d/vcr...
# condition                                                                             new
# providerId                                                                            199
# createdAt                                                        2024-08-27T04:40:59.372Z
# updatedAt                                                        2024-08-27T04:40:59.372Z
# modelId                                                                               883
# dealerName                                                                Copeland Toyota
# active                                                                               True
# state                                                                                  MA
# trim                                                                                  XLE
# clickoffUrl
# acceptsLeads                                                                         True
# bodyType                                                                            sedan
# bodyStyle                                                                           sedan
# regionName                                                                           None
# experience                                                                          local
# requiresAddressWithLead                                                             False
# providerGroupId                                                                       229
# mileageUnformatted                                                                    NaN
# mileageHumanized                                                                      New
# priceMobile                                                                       $41,523
# priceUnformatted                                                                    41523
# recentPriceDrop                                                                     False
# vdpUrl                                                /toyota-camry#vin=4T1DBADK7SU007709
# showNewMileage                                                                       True
# eligibleForFinancing                                                                 True
# financingExperience                                                              softpull
# photoUrls                               [https://auto.dev/image/fetch/s--8KWZEbYy--/c_...
# isHot                                                                               False
# hrefTarget                                                    /listings/4T1DBADK7SU007709
# distanceFromOrigin                                                                     21
# humanizedSearchLocation                                                              None
# hideDistance                                                                         None
# noPriceText                                                                          None
# target                                                                               None
# monthlyPayment                                                                   -7480706
# clickOff                                                                            False
# emailOptDefault                                                                      True
# showThankyouPage                                                                    False
# showRsrp                                                                             True
# allowOneClickSubmit                                                                  True
# paidAllowOneClickSubmit                                                              True
# newPriceAsMsrp                                                                      False
# preCheckThankyou                                                                     True
# preCheckThankyouMobile                                                               True
# openInNewWindow                                                                     False
# alwaysAskForZip                                                                     False
# requireEmailOptIn                                                                   False
# providerName                                                                     auto_dev
# availableNationwide                                                                 False
# regional                                                                            False
# thumbnailUrl                            https://auto.dev/image/fetch/s--SgA0dzBe--/c_f...
# thumbnailUrlLarge                       https://auto.dev/image/fetch/s--8KWZEbYy--/c_f...
# quickPicksEligible                                                                   True
# dealerGroupUuid                                                                      None
# cplValue                                                                                3
# partnerType                                                                    metasearch
# trackingParams.idFromProvider                                                   394463309
# trackingParams.remoteDealerId                                                       54419
# trackingParams.dealerName                                                            None
# trackingParams.remoteSku
# trackingParams.experience                                                           local
# trackingParams.rooftopUniqueName                                                     None
# trackingParams.rooftopUuid                                                           None
# trackingParams.dealerUniqueName                                                      None
# trackingParams.dealerUuid                                                            None
# trackingParams.dealerGroupUniqueName                                                 None
# trackingParams.dealerGroupUuid                                                       None
# Name: 1, dtype: object

# %% [markdown]
# #### Part 3: Clean data
# Three car features are included in this model:
# - Model Year
# - Mileage
# - Body Trim

# %%
def convert_mileage(value):
    value = value.strip()
    if value.lower() == 'new':
        return 0
    try:
        # Remove non-numeric characters and convert to int
        return int(value.replace(',', '').replace(' Miles', ''))
    except ValueError:
        # Handle unexpected cases
        return None

def convert_year(value):
    value = 2025 - value + 1
    return math.log(value)

def convert_price(value):
    if isinstance(value, str):
        value = value.replace('$', '').replace(',', '')
        try:
            return float(value)
        except ValueError:
            return None
    return None

# %%
X = df[['year', 'mileageUnformatted', 'priceUnformatted', 'trim']]

X = X.dropna()

# %%
X_mod.iloc[1]
# Out:
# const                     1.000000
# mileageUnformatted    63131.000000
# trim_SE                   0.000000
# trim_XLE                  1.000000
# trim_XSE                  0.000000
# year_2016                 0.000000
# year_2017                 1.000000
# year_2018                 0.000000
# year_2019                 0.000000
# year_2020                 0.000000
# year_2021                 0.000000
# year_2022                 0.000000
# year_2023                 0.000000
# year_2024                 0.000000
# year                      2.197225
# Name: 2, dtype: float64

# %%
# Define the trims you want to include
trims_to_filter = ['SE', 'LE', 'XSE', 'XLE']

# Filter out any unwanted trims
X_mod = X[X['trim'].isin(trims_to_filter)]
y = X_mod.pop('priceUnformatted')

# Convert remaining trims into categorical data types
X_mod['trim'] = X_mod['trim'].astype('category')
X_mod = pd.get_dummies(X_mod, columns=['trim'], drop_first=True)


X_mod = sm.add_constant(X_mod)

# Allow each model year to have an additional affect beyond the existing logarithmic effect
temp = X_mod['year']
X_mod = pd.get_dummies(X_mod, columns=['year'], drop_first=False)
X_mod.pop('year_2025')

X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
X_mod['year'] = temp.apply(convert_year)
# Out:
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['trim'] = X_mod['trim'].astype('category')
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      1
# 2      0
# 3      0
# 4      1
# 6      0
#       ..
# 787    1
# 788    0
# 789    0
# 791    0
# 792    0
# Name: trim_SE, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      1
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: trim_XLE, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    1
# Name: trim_XSE, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      1
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2016, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      1
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    1
# 789    0
# 791    0
# 792    1
# Name: year_2017, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2018, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2019, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    1
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2020, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    1
# 791    0
# 792    0
# Name: year_2021, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      1
# 2      0
# 3      0
# 4      0
# 6      1
#       ..
# 787    0
# 788    0
# 789    0
# 791    1
# 792    0
# Name: year_2022, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2023, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)
# /var/folders/zf/q6vckqdx64v8bb5_y2dtjvjw0000gn/T/ipykernel_73035/3822541066.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0      0
# 2      0
# 3      0
# 4      0
# 6      0
#       ..
# 787    0
# 788    0
# 789    0
# 791    0
# 792    0
# Name: year_2024, Length: 600, dtype: int64' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   X_mod.iloc[:, range(2,14)] = X_mod.iloc[:, range(2,14)].astype(int)

# %% [markdown]
# #### Part 4: Build model

# %%
regression_model = sm.GLM(y, X_mod, family=sm.families.Gaussian()).fit()

# Print the summary of the model
print(regression_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       priceUnformatted   No. Observations:                  600
# Model:                            GLM   Df Residuals:                      586
# Model Family:                Gaussian   Df Model:                           13
# Link Function:               Identity   Scale:                      3.8060e+06
# Method:                          IRLS   Log-Likelihood:                -5389.9
# Date:                Tue, 27 Aug 2024   Deviance:                   2.2303e+09
# Time:                        11:11:18   Pearson chi2:                 2.23e+09
# No. Iterations:                     3   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               3.485e+04    180.967    192.573      0.000    3.45e+04    3.52e+04
# mileageUnformatted    -0.0666      0.004    -17.458      0.000      -0.074      -0.059
# trim_SE              757.9916    181.865      4.168      0.000     401.542    1114.441
# trim_XLE            3942.0173    293.451     13.433      0.000    3366.864    4517.171
# trim_XSE            4951.5116    269.137     18.398      0.000    4424.013    5479.011
# year_2016          -1059.3203    336.242     -3.150      0.002   -1718.343    -400.298
# year_2017          -1607.8351    308.521     -5.211      0.000   -2212.525   -1003.145
# year_2018           -137.5725    288.184     -0.477      0.633    -702.403     427.258
# year_2019            646.0091    285.523      2.263      0.024      86.395    1205.623
# year_2020           -168.7158    274.030     -0.616      0.538    -705.804     368.372
# year_2021            202.4573    225.785      0.897      0.370    -240.073     644.987
# year_2022            214.1618    243.418      0.880      0.379    -262.929     691.253
# year_2023           -189.8995    248.699     -0.764      0.445    -677.340     297.541
# year_2024          -1174.5509    342.170     -3.433      0.001   -1845.193    -503.909
# year               -5703.2751    167.664    -34.016      0.000   -6031.890   -5374.661
# ======================================================================================

# %% [markdown]
# #### Part 5: Evaluate model
#
# This section calculates the estimated price of a car based on input features. Cars with large discounts (difference between predicted price and actual price) are identified.

# %%
new_car = pd.DataFrame({'const': [1], 
                        'mileageUnformatted': [39000],
                        'trim_SE': [0],
                        'trim_XLE': [1],
                        'trim_XSE': [0],
                        'year_2016': [0],
                        'year_2017': [0],
                        'year_2018': [1],
                        'year_2019': [0],
                        'year_2020': [0],
                        'year_2021': [0],
                        'year_2022': [0],
                        'year_2023': [0],
                        'year_2024': [0],
                        'year': math.log(8)
                       })
# Predict the price
regression_model.predict(new_car)
# Out:
# 0    24195.205886
# dtype: float64

# %%
regression_model.resid_pearson[regression_model.resid_pearson < -4000]
# Out:
# 40    -4980.049150
# 99    -4600.982509
# 169   -4536.049150
# 184   -4766.786471
# 188   -5808.715945
# 373   -4740.249072
# 455   -4523.174079
# dtype: float64

# %%
pd.set_option('display.max_rows', 100)
df.iloc[184]
# Out:
# id                                                                              295040237
# vin                                                                     4T1BF1FK9GU540290
# displayColor                                                    Celestial Silver Metallic
# year                                                                                 2016
# make                                                                               Toyota
# model                                                                               Camry
# price                                                                             $16,995
# mileage                                                                      57,735 Miles
# city                                                                             Johnston
# lat                                                                               41.8647
# lon                                                                              -71.4976
# primaryPhotoUrl                         https://InvImg2B.autofunds.net/InventoryImages...
# condition                                                                            used
# providerId                                                                            199
# createdAt                                                        2024-08-20T17:55:52.114Z
# updatedAt                                                        2024-08-25T03:47:32.965Z
# modelId                                                                               883
# dealerName                                                         Ocean State Auto Sales
# active                                                                               True
# state                                                                                  RI
# trim                                                                                  XSE
# clickoffUrl
# acceptsLeads                                                                         True
# bodyType                                                                            sedan
# bodyStyle                                                                           sedan
# regionName                                                                           None
# experience                                                                          local
# requiresAddressWithLead                                                             False
# providerGroupId                                                                       229
# mileageUnformatted                                                                57735.0
# mileageHumanized                                                                58k Miles
# priceMobile                                                                       $16,995
# priceUnformatted                                                                    16995
# recentPriceDrop                                                                     False
# vdpUrl                                                /toyota-camry#vin=4T1BF1FK9GU540290
# showNewMileage                                                                      False
# eligibleForFinancing                                                                False
# financingExperience                                                                  none
# photoUrls                               [https://auto.dev/image/fetch/s--Cc7Wl5Pr--/c_...
# isHot                                                                               False
# hrefTarget                                                    /listings/4T1BF1FK9GU540290
# distanceFromOrigin                                                                     40
# humanizedSearchLocation                                                              None
# hideDistance                                                                         None
# noPriceText                                                                          None
# target                                                                               None
# monthlyPayment                                                                   -3061787
# clickOff                                                                            False
# emailOptDefault                                                                      True
# showThankyouPage                                                                    False
# showRsrp                                                                             True
# allowOneClickSubmit                                                                  True
# paidAllowOneClickSubmit                                                              True
# newPriceAsMsrp                                                                      False
# preCheckThankyou                                                                     True
# preCheckThankyouMobile                                                               True
# openInNewWindow                                                                     False
# alwaysAskForZip                                                                     False
# requireEmailOptIn                                                                   False
# providerName                                                                     auto_dev
# availableNationwide                                                                 False
# regional                                                                            False
# thumbnailUrl                            https://auto.dev/image/fetch/s--aML8n_XX--/c_f...
# thumbnailUrlLarge                       https://auto.dev/image/fetch/s--Cc7Wl5Pr--/c_f...
# quickPicksEligible                                                                   True
# dealerGroupUuid                                                                      None
# cplValue                                                                                3
# partnerType                                                                    metasearch
# trackingParams.idFromProvider                                                   393818964
# trackingParams.remoteDealerId                                                      437972
# trackingParams.dealerName                                                            None
# trackingParams.remoteSku                                                           540290
# trackingParams.experience                                                           local
# trackingParams.rooftopUniqueName                                                     None
# trackingParams.rooftopUuid                                                           None
# trackingParams.dealerUniqueName                                                      None
# trackingParams.dealerUuid                                                            None
# trackingParams.dealerGroupUniqueName                                                 None
# trackingParams.dealerGroupUuid                                                       None
# Name: 184, dtype: object

# %% [markdown]
# #### Part 6: Automate a daily newsletter

# %%
# %run daily_newsletter.py
# Out:
# Page 1: All records are within the last 24 hours.
# Found an entry older than 24 hours, stopping the loop.
# /Users/maxmelnikas/Documents/Personal Projects/Cars/daily_newsletter.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['estimate_price'] = X_mod.apply(calculate_price, axis=1)
# /Users/maxmelnikas/Documents/Personal Projects/Cars/daily_newsletter.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_mod['discount'] = X_mod['estimate_price'] - X_mod['priceUnformatted']
# /Users/maxmelnikas/Documents/Personal Projects/Cars/helper_functions.py:124: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master = pd.concat([master, X_filtered], ignore_index=True)
# /Users/maxmelnikas/Documents/Personal Projects/Cars/helper_functions.py:149: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   daily = pd.concat([daily, new_entry], ignore_index=True)

# %% [markdown]
# ## Appendix

# %%
from helper_functions import update_latest_logs

update_latest_logs()

# %%
from datetime import datetime, timezone
datetime.now(timezone.utc)
# Out:
# datetime.datetime(2024, 9, 6, 1, 16, 17, 736288, tzinfo=datetime.timezone.utc)
